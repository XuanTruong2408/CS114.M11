# %%
import tensorflow 

import pandas as pd
import numpy as np
import os
import keras
import random
import cv2
import math
import seaborn as sns

from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt

from tensorflow.keras.layers import Dense,GlobalAveragePooling2D,Convolution2D,BatchNormalization
from tensorflow.keras.layers import Flatten,MaxPooling2D,Dropout

from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.applications.densenet import preprocess_input

from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,img_to_array

from tensorflow.keras.models import Model

from tensorflow.keras.optimizers import Adam

from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

import warnings

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
fruits_dir = os.path.join('/content/drive/MyDrive/CS114.M11/train_dataset/fruits')
cat_dir = os.path.join('/content/drive/MyDrive/CS114.M11/train_dataset/cat')
dog_dir = os.path.join('/content/drive/MyDrive/CS114.M11/train_dataset/dog')
beach_dir = os.path.join('/content/drive/MyDrive/CS114.M11/train_dataset/beach')
bill_dir = os.path.join('/content/drive/MyDrive/CS114.M11/train_dataset/bill')
bookjacket_dir = os.path.join('/content/drive/MyDrive/CS114.M11/train_dataset/bookjacket')
car_dir = os.path.join('/content/drive/MyDrive/CS114.M11/train_dataset/car')
clothes_dir = os.path.join('/content/drive/MyDrive/CS114.M11/train_dataset/clothes')
drink_dir = os.path.join('/content/drive/MyDrive/CS114.M11/train_dataset/drink')
feast_dir = os.path.join('/content/drive/MyDrive/CS114.M11/train_dataset/feast')
field_dir = os.path.join('/content/drive/MyDrive/CS114.M11/train_dataset/field')
flower_dir = os.path.join('/content/drive/MyDrive/CS114.M11/train_dataset/flower')
food_dir = os.path.join('/content/drive/MyDrive/CS114.M11/train_dataset/food')
house_dir = os.path.join('/content/drive/MyDrive/CS114.M11/train_dataset/house')
jewels_dir = os.path.join('/content/drive/MyDrive/CS114.M11/train_dataset/jewels')
motorcycle_dir = os.path.join('/content/drive/MyDrive/CS114.M11/train_dataset/motorcycle')
mountain_dir = os.path.join('/content/drive/MyDrive/CS114.M11/train_dataset/mountain')
papers_dir = os.path.join('/content/drive/MyDrive/CS114.M11/train_dataset/papers')
person_dir = os.path.join('/content/drive/MyDrive/CS114.M11/train_dataset/person')
shoe_dir = os.path.join('/content/drive/MyDrive/CS114.M11/train_dataset/shoe')
truck_dir = os.path.join('/content/drive/MyDrive/CS114.M11/train_dataset/truck')

# %%
print('Total training fruits images:', len(os.listdir(fruits_dir)))
print('Total training cat images:', len(os.listdir(cat_dir)))
print('Total training dog images:', len(os.listdir(dog_dir)))
print('Total training beach images:', len(os.listdir(beach_dir)))
print('Total training bill images:', len(os.listdir(bill_dir)))
print('Total training bookjacket images:', len(os.listdir(bookjacket_dir)))
print('Total training car images:', len(os.listdir(car_dir)))
print('Total training clothes images:', len(os.listdir(clothes_dir)))
print('Total training drink images:', len(os.listdir(drink_dir)))
print('Total training feast images:', len(os.listdir(feast_dir)))
print('Total training field images:', len(os.listdir(field_dir)))
print('Total training flower images:', len(os.listdir(flower_dir)))
print('Total training food images:', len(os.listdir(food_dir)))
print('Total training house images:', len(os.listdir(house_dir)))
print('Total training jewels images:', len(os.listdir(jewels_dir)))
print('Total training motorcycle images:', len(os.listdir(motorcycle_dir)))
print('Total training mountain images:', len(os.listdir(mountain_dir)))
print('Total training papers images:', len(os.listdir(papers_dir)))
print('Total training person images:', len(os.listdir(person_dir)))
print('Total training shoe images:', len(os.listdir(shoe_dir)))
print('Total training truck images:', len(os.listdir(truck_dir)))
# Out:
# Total training fruits images: 157
# Total training cat images: 316
# Total training dog images: 293
# Total training beach images: 287
# Total training bill images: 108
# Total training bookjacket images: 217
# Total training car images: 114
# Total training clothes images: 188
# Total training drink images: 167
# Total training feast images: 110
# Total training field images: 126
# Total training flower images: 276
# Total training food images: 218
# Total training house images: 111
# Total training jewels images: 117
# Total training motorcycle images: 211
# Total training mountain images: 107
# Total training papers images: 125
# Total training person images: 184
# Total training shoe images: 355
# Total training truck images: 149

# %% [markdown]
# ## data train

# %%
data_train=[]
labels_train=[]
random.seed(42)
imagePaths_train = sorted(list(os.listdir("/content/drive/MyDrive/CS114.M11/train_dataset/")))
random.shuffle(imagePaths_train)
print(imagePaths_train)
# Out:
# ['shoe', 'clothes', 'jewels', 'cat', 'field', 'house', 'motorcycle', 'person', 'dog', 'fruits', 'papers', 'flower', 'bill', 'food', 'bookjacket', 'mountain', 'drink', 'feast', 'beach', 'car', 'truck']

# %%
for img in imagePaths_train:
    path=sorted(list(os.listdir("/content/drive/MyDrive/CS114.M11/train_dataset/"+img)))
    for i in path:
        image = cv2.imread("/content/drive/MyDrive/CS114.M11/train_dataset/"+ img + '/' + i)
        image = cv2.resize(image, (124, 124))
        image = img_to_array(image)
        data_train.append(image)
        l = label = img
        labels_train.append(l)

# %%
data_train = np.array(data_train, dtype="float32") / 255.0
labels_train = np.array(labels_train)
mlb = LabelBinarizer()
labels_train = mlb.fit_transform(labels_train)

# %% [markdown]
# ## data test

# %%
data_test=[]
labels_test=[]
random.seed(42)
imagePaths_test = sorted(list(os.listdir("/content/drive/MyDrive/CS114.M11/test_dataset/")))
random.shuffle(imagePaths_test)
print(imagePaths_test)
# Out:
# ['shoe', 'clothes', 'jewels', 'cat', 'field', 'house', 'motorcycle', 'person', 'dog', 'fruits', 'papers', 'flower', 'bill', 'food', 'bookjacket', 'mountain', 'drink', 'feast', 'beach', 'car', 'truck']

# %%
for img in imagePaths_test:
    path=sorted(list(os.listdir("/content/drive/MyDrive/CS114.M11/test_dataset/"+img)))
    for i in path:
        image = cv2.imread("/content/drive/MyDrive/CS114.M11/test_dataset/"+ img + '/' + i)
        image = cv2.resize(image, (124, 124))
        image = img_to_array(image)
        data_test.append(image)
        l = label = img
        labels_test.append(l)

# %%
data_test = np.array(data_test, dtype="float32") / 255.0
labels_test = np.array(labels_test)
mlb = LabelBinarizer()
labels_test = mlb.fit_transform(labels_test)

# %% [markdown]
# # model

# %%
model_d=DenseNet121(weights='imagenet',include_top=False, input_shape=(124, 124, 3)) 


for layer in model_d.layers:
    layer.trainable = False

x=model_d.output

x= GlobalAveragePooling2D()(x)
x= BatchNormalization()(x)
x= Dropout(0.5)(x)
x= Dense(1024,activation='relu')(x) 
x= Dense(512,activation='relu')(x) 
x= BatchNormalization()(x)
x= Dropout(0.5)(x)

preds=Dense(21,activation='softmax')(x) #FC-layer

# %%
model=Model(inputs=model_d.input,outputs=preds)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 124, 124, 3  0           []
#                                 )]
#
#  zero_padding2d (ZeroPadding2D)  (None, 130, 130, 3)  0          ['input_1[0][0]']
#
#  conv1/conv (Conv2D)            (None, 62, 62, 64)   9408        ['zero_padding2d[0][0]']
#
#  conv1/bn (BatchNormalization)  (None, 62, 62, 64)   256         ['conv1/conv[0][0]']
#
#  conv1/relu (Activation)        (None, 62, 62, 64)   0           ['conv1/bn[0][0]']
#
#  zero_padding2d_1 (ZeroPadding2  (None, 64, 64, 64)  0           ['conv1/relu[0][0]']
#  D)
#
#  pool1 (MaxPooling2D)           (None, 31, 31, 64)   0           ['zero_padding2d_1[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 31, 31, 64)  256         ['pool1[0][0]']
#  ization)
#
#  conv2_block1_0_relu (Activatio  (None, 31, 31, 64)  0           ['conv2_block1_0_bn[0][0]']
#  n)
#
#  conv2_block1_1_conv (Conv2D)   (None, 31, 31, 128)  8192        ['conv2_block1_0_relu[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 31, 31, 128)  512        ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 31, 31, 128)  0          ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 31, 31, 32)   36864       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_concat (Concatena  (None, 31, 31, 96)  0           ['pool1[0][0]',
#  te)                                                              'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 31, 31, 96)  384         ['conv2_block1_concat[0][0]']
#  ization)
#
#  conv2_block2_0_relu (Activatio  (None, 31, 31, 96)  0           ['conv2_block2_0_bn[0][0]']
#  n)
#
#  conv2_block2_1_conv (Conv2D)   (None, 31, 31, 128)  12288       ['conv2_block2_0_relu[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 31, 31, 128)  512        ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 31, 31, 128)  0          ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 31, 31, 32)   36864       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_concat (Concatena  (None, 31, 31, 128)  0          ['conv2_block1_concat[0][0]',
#  te)                                                              'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 31, 31, 128)  512        ['conv2_block2_concat[0][0]']
#  ization)
#
#  conv2_block3_0_relu (Activatio  (None, 31, 31, 128)  0          ['conv2_block3_0_bn[0][0]']
#  n)
#
#  conv2_block3_1_conv (Conv2D)   (None, 31, 31, 128)  16384       ['conv2_block3_0_relu[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 31, 31, 128)  512        ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 31, 31, 128)  0          ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 31, 31, 32)   36864       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_concat (Concatena  (None, 31, 31, 160)  0          ['conv2_block2_concat[0][0]',
#  te)                                                              'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 31, 31, 160)  640        ['conv2_block3_concat[0][0]']
#  ization)
#
#  conv2_block4_0_relu (Activatio  (None, 31, 31, 160)  0          ['conv2_block4_0_bn[0][0]']
#  n)
#
#  conv2_block4_1_conv (Conv2D)   (None, 31, 31, 128)  20480       ['conv2_block4_0_relu[0][0]']
#
#  conv2_block4_1_bn (BatchNormal  (None, 31, 31, 128)  512        ['conv2_block4_1_conv[0][0]']
#  ization)
#
#  conv2_block4_1_relu (Activatio  (None, 31, 31, 128)  0          ['conv2_block4_1_bn[0][0]']
#  n)
#
#  conv2_block4_2_conv (Conv2D)   (None, 31, 31, 32)   36864       ['conv2_block4_1_relu[0][0]']
#
#  conv2_block4_concat (Concatena  (None, 31, 31, 192)  0          ['conv2_block3_concat[0][0]',
#  te)                                                              'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 31, 31, 192)  768        ['conv2_block4_concat[0][0]']
#  ization)
#
#  conv2_block5_0_relu (Activatio  (None, 31, 31, 192)  0          ['conv2_block5_0_bn[0][0]']
#  n)
#
#  conv2_block5_1_conv (Conv2D)   (None, 31, 31, 128)  24576       ['conv2_block5_0_relu[0][0]']
#
#  conv2_block5_1_bn (BatchNormal  (None, 31, 31, 128)  512        ['conv2_block5_1_conv[0][0]']
#  ization)
#
#  conv2_block5_1_relu (Activatio  (None, 31, 31, 128)  0          ['conv2_block5_1_bn[0][0]']
#  n)
#
#  conv2_block5_2_conv (Conv2D)   (None, 31, 31, 32)   36864       ['conv2_block5_1_relu[0][0]']
#
#  conv2_block5_concat (Concatena  (None, 31, 31, 224)  0          ['conv2_block4_concat[0][0]',
#  te)                                                              'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 31, 31, 224)  896        ['conv2_block5_concat[0][0]']
#  ization)
#
#  conv2_block6_0_relu (Activatio  (None, 31, 31, 224)  0          ['conv2_block6_0_bn[0][0]']
#  n)
#
#  conv2_block6_1_conv (Conv2D)   (None, 31, 31, 128)  28672       ['conv2_block6_0_relu[0][0]']
#
#  conv2_block6_1_bn (BatchNormal  (None, 31, 31, 128)  512        ['conv2_block6_1_conv[0][0]']
#  ization)
#
#  conv2_block6_1_relu (Activatio  (None, 31, 31, 128)  0          ['conv2_block6_1_bn[0][0]']
#  n)
#
#  conv2_block6_2_conv (Conv2D)   (None, 31, 31, 32)   36864       ['conv2_block6_1_relu[0][0]']
#
#  conv2_block6_concat (Concatena  (None, 31, 31, 256)  0          ['conv2_block5_concat[0][0]',
#  te)                                                              'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 31, 31, 256)  1024        ['conv2_block6_concat[0][0]']
#
#  pool2_relu (Activation)        (None, 31, 31, 256)  0           ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)            (None, 31, 31, 128)  32768       ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling2D)  (None, 15, 15, 128)  0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 15, 15, 128)  512        ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 15, 15, 128)  0          ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 15, 15, 128)  16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 15, 15, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 15, 15, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 15, 15, 32)   36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 15, 15, 160)  0          ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 15, 15, 160)  640        ['conv3_block1_concat[0][0]']
#  ization)
#
#  conv3_block2_0_relu (Activatio  (None, 15, 15, 160)  0          ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 15, 15, 128)  20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 15, 15, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 15, 15, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 15, 15, 32)   36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 15, 15, 192)  0          ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 15, 15, 192)  768        ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 15, 15, 192)  0          ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 15, 15, 128)  24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 15, 15, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 15, 15, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 15, 15, 32)   36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 15, 15, 224)  0          ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 15, 15, 224)  896        ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 15, 15, 224)  0          ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 15, 15, 128)  28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 15, 15, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 15, 15, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 15, 15, 32)   36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 15, 15, 256)  0          ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 15, 15, 256)  1024       ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 15, 15, 256)  0          ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 15, 15, 128)  32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 15, 15, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 15, 15, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 15, 15, 32)   36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 15, 15, 288)  0          ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 15, 15, 288)  1152       ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 15, 15, 288)  0          ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 15, 15, 128)  36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 15, 15, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 15, 15, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 15, 15, 32)   36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 15, 15, 320)  0          ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 15, 15, 320)  1280       ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 15, 15, 320)  0          ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 15, 15, 128)  40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 15, 15, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 15, 15, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 15, 15, 32)   36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 15, 15, 352)  0          ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 15, 15, 352)  1408       ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 15, 15, 352)  0          ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 15, 15, 128)  45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 15, 15, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 15, 15, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 15, 15, 32)   36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 15, 15, 384)  0          ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 15, 15, 384)  1536       ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 15, 15, 384)  0          ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 15, 15, 128)  49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 15, 15, 128)  512        ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 15, 15, 128)  0          ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 15, 15, 32)   36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 15, 15, 416)  0          ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 15, 15, 416)  1664       ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 15, 15, 416)  0          ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 15, 15, 128)  53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 15, 15, 128)  512        ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 15, 15, 128)  0          ['conv3_block10_1_bn[0][0]']
#  on)
#
#  conv3_block10_2_conv (Conv2D)  (None, 15, 15, 32)   36864       ['conv3_block10_1_relu[0][0]']
#
#  conv3_block10_concat (Concaten  (None, 15, 15, 448)  0          ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 15, 15, 448)  1792       ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 15, 15, 448)  0          ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 15, 15, 128)  57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 15, 15, 128)  512        ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 15, 15, 128)  0          ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 15, 15, 32)   36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 15, 15, 480)  0          ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 15, 15, 480)  1920       ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 15, 15, 480)  0          ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 15, 15, 128)  61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 15, 15, 128)  512        ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 15, 15, 128)  0          ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 15, 15, 32)   36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 15, 15, 512)  0          ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 15, 15, 512)  2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 15, 15, 512)  0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 15, 15, 256)  131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 7, 7, 256)    0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 7, 7, 256)   1024        ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 7, 7, 128)    32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 7, 7, 128)   512         ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 7, 7, 128)   0           ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 7, 7, 32)     36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 7, 7, 288)   0           ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, 7, 7, 288)   1152        ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 7, 7, 288)   0           ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 7, 7, 128)    36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 7, 7, 128)   512         ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 7, 7, 128)   0           ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 7, 7, 32)     36864       ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_concat (Concatena  (None, 7, 7, 320)   0           ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 7, 7, 320)   1280        ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 7, 7, 320)   0           ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 7, 7, 128)    40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 7, 7, 128)   512         ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 7, 7, 128)   0           ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 7, 7, 32)     36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 7, 7, 352)   0           ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 7, 7, 352)   1408        ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 7, 7, 352)   0           ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 7, 7, 128)    45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 7, 7, 128)   512         ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 7, 7, 128)   0           ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 7, 7, 32)     36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 7, 7, 384)   0           ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 7, 7, 384)   1536        ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 7, 7, 384)   0           ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 7, 7, 128)    49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 7, 7, 128)   512         ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 7, 7, 128)   0           ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 7, 7, 32)     36864       ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_concat (Concatena  (None, 7, 7, 416)   0           ['conv4_block4_concat[0][0]',
#  te)                                                              'conv4_block5_2_conv[0][0]']
#
#  conv4_block6_0_bn (BatchNormal  (None, 7, 7, 416)   1664        ['conv4_block5_concat[0][0]']
#  ization)
#
#  conv4_block6_0_relu (Activatio  (None, 7, 7, 416)   0           ['conv4_block6_0_bn[0][0]']
#  n)
#
#  conv4_block6_1_conv (Conv2D)   (None, 7, 7, 128)    53248       ['conv4_block6_0_relu[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 7, 7, 128)   512         ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 7, 7, 128)   0           ['conv4_block6_1_bn[0][0]']
# ...
#  te)                                                              'conv5_block9_2_conv[0][0]']
#
#  conv5_block10_0_bn (BatchNorma  (None, 3, 3, 800)   3200        ['conv5_block9_concat[0][0]']
#  lization)
#
#  conv5_block10_0_relu (Activati  (None, 3, 3, 800)   0           ['conv5_block10_0_bn[0][0]']
#  on)
#
#  conv5_block10_1_conv (Conv2D)  (None, 3, 3, 128)    102400      ['conv5_block10_0_relu[0][0]']
#
#  conv5_block10_1_bn (BatchNorma  (None, 3, 3, 128)   512         ['conv5_block10_1_conv[0][0]']
#  lization)
#
#  conv5_block10_1_relu (Activati  (None, 3, 3, 128)   0           ['conv5_block10_1_bn[0][0]']
#  on)
#
#  conv5_block10_2_conv (Conv2D)  (None, 3, 3, 32)     36864       ['conv5_block10_1_relu[0][0]']
#
#  conv5_block10_concat (Concaten  (None, 3, 3, 832)   0           ['conv5_block9_concat[0][0]',
#  ate)                                                             'conv5_block10_2_conv[0][0]']
#
#  conv5_block11_0_bn (BatchNorma  (None, 3, 3, 832)   3328        ['conv5_block10_concat[0][0]']
#  lization)
#
#  conv5_block11_0_relu (Activati  (None, 3, 3, 832)   0           ['conv5_block11_0_bn[0][0]']
#  on)
#
#  conv5_block11_1_conv (Conv2D)  (None, 3, 3, 128)    106496      ['conv5_block11_0_relu[0][0]']
#
#  conv5_block11_1_bn (BatchNorma  (None, 3, 3, 128)   512         ['conv5_block11_1_conv[0][0]']
#  lization)
#
#  conv5_block11_1_relu (Activati  (None, 3, 3, 128)   0           ['conv5_block11_1_bn[0][0]']
#  on)
#
#  conv5_block11_2_conv (Conv2D)  (None, 3, 3, 32)     36864       ['conv5_block11_1_relu[0][0]']
#
#  conv5_block11_concat (Concaten  (None, 3, 3, 864)   0           ['conv5_block10_concat[0][0]',
#  ate)                                                             'conv5_block11_2_conv[0][0]']
#
#  conv5_block12_0_bn (BatchNorma  (None, 3, 3, 864)   3456        ['conv5_block11_concat[0][0]']
#  lization)
#
#  conv5_block12_0_relu (Activati  (None, 3, 3, 864)   0           ['conv5_block12_0_bn[0][0]']
#  on)
#
#  conv5_block12_1_conv (Conv2D)  (None, 3, 3, 128)    110592      ['conv5_block12_0_relu[0][0]']
#
#  conv5_block12_1_bn (BatchNorma  (None, 3, 3, 128)   512         ['conv5_block12_1_conv[0][0]']
#  lization)
#
#  conv5_block12_1_relu (Activati  (None, 3, 3, 128)   0           ['conv5_block12_1_bn[0][0]']
#  on)
#
#  conv5_block12_2_conv (Conv2D)  (None, 3, 3, 32)     36864       ['conv5_block12_1_relu[0][0]']
#
#  conv5_block12_concat (Concaten  (None, 3, 3, 896)   0           ['conv5_block11_concat[0][0]',
#  ate)                                                             'conv5_block12_2_conv[0][0]']
#
#  conv5_block13_0_bn (BatchNorma  (None, 3, 3, 896)   3584        ['conv5_block12_concat[0][0]']
#  lization)
#
#  conv5_block13_0_relu (Activati  (None, 3, 3, 896)   0           ['conv5_block13_0_bn[0][0]']
#  on)
#
#  conv5_block13_1_conv (Conv2D)  (None, 3, 3, 128)    114688      ['conv5_block13_0_relu[0][0]']
#
#  conv5_block13_1_bn (BatchNorma  (None, 3, 3, 128)   512         ['conv5_block13_1_conv[0][0]']
#  lization)
#
#  conv5_block13_1_relu (Activati  (None, 3, 3, 128)   0           ['conv5_block13_1_bn[0][0]']
#  on)
#
#  conv5_block13_2_conv (Conv2D)  (None, 3, 3, 32)     36864       ['conv5_block13_1_relu[0][0]']
#
#  conv5_block13_concat (Concaten  (None, 3, 3, 928)   0           ['conv5_block12_concat[0][0]',
#  ate)                                                             'conv5_block13_2_conv[0][0]']
#
#  conv5_block14_0_bn (BatchNorma  (None, 3, 3, 928)   3712        ['conv5_block13_concat[0][0]']
#  lization)
#
#  conv5_block14_0_relu (Activati  (None, 3, 3, 928)   0           ['conv5_block14_0_bn[0][0]']
#  on)
#
#  conv5_block14_1_conv (Conv2D)  (None, 3, 3, 128)    118784      ['conv5_block14_0_relu[0][0]']
#
#  conv5_block14_1_bn (BatchNorma  (None, 3, 3, 128)   512         ['conv5_block14_1_conv[0][0]']
#  lization)
#
#  conv5_block14_1_relu (Activati  (None, 3, 3, 128)   0           ['conv5_block14_1_bn[0][0]']
#  on)
#
#  conv5_block14_2_conv (Conv2D)  (None, 3, 3, 32)     36864       ['conv5_block14_1_relu[0][0]']
#
#  conv5_block14_concat (Concaten  (None, 3, 3, 960)   0           ['conv5_block13_concat[0][0]',
#  ate)                                                             'conv5_block14_2_conv[0][0]']
#
#  conv5_block15_0_bn (BatchNorma  (None, 3, 3, 960)   3840        ['conv5_block14_concat[0][0]']
#  lization)
#
#  conv5_block15_0_relu (Activati  (None, 3, 3, 960)   0           ['conv5_block15_0_bn[0][0]']
#  on)
#
#  conv5_block15_1_conv (Conv2D)  (None, 3, 3, 128)    122880      ['conv5_block15_0_relu[0][0]']
#
#  conv5_block15_1_bn (BatchNorma  (None, 3, 3, 128)   512         ['conv5_block15_1_conv[0][0]']
#  lization)
#
#  conv5_block15_1_relu (Activati  (None, 3, 3, 128)   0           ['conv5_block15_1_bn[0][0]']
#  on)
#
#  conv5_block15_2_conv (Conv2D)  (None, 3, 3, 32)     36864       ['conv5_block15_1_relu[0][0]']
#
#  conv5_block15_concat (Concaten  (None, 3, 3, 992)   0           ['conv5_block14_concat[0][0]',
#  ate)                                                             'conv5_block15_2_conv[0][0]']
#
#  conv5_block16_0_bn (BatchNorma  (None, 3, 3, 992)   3968        ['conv5_block15_concat[0][0]']
#  lization)
#
#  conv5_block16_0_relu (Activati  (None, 3, 3, 992)   0           ['conv5_block16_0_bn[0][0]']
#  on)
#
#  conv5_block16_1_conv (Conv2D)  (None, 3, 3, 128)    126976      ['conv5_block16_0_relu[0][0]']
#
#  conv5_block16_1_bn (BatchNorma  (None, 3, 3, 128)   512         ['conv5_block16_1_conv[0][0]']
#  lization)
#
#  conv5_block16_1_relu (Activati  (None, 3, 3, 128)   0           ['conv5_block16_1_bn[0][0]']
#  on)
#
#  conv5_block16_2_conv (Conv2D)  (None, 3, 3, 32)     36864       ['conv5_block16_1_relu[0][0]']
#
#  conv5_block16_concat (Concaten  (None, 3, 3, 1024)  0           ['conv5_block15_concat[0][0]',
#  ate)                                                             'conv5_block16_2_conv[0][0]']
#
#  bn (BatchNormalization)        (None, 3, 3, 1024)   4096        ['conv5_block16_concat[0][0]']
#
#  relu (Activation)              (None, 3, 3, 1024)   0           ['bn[0][0]']
#
#  global_average_pooling2d (Glob  (None, 1024)        0           ['relu[0][0]']
#  alAveragePooling2D)
#
#  batch_normalization (BatchNorm  (None, 1024)        4096        ['global_average_pooling2d[0][0]'
#  alization)                                                      ]
#
#  dropout (Dropout)              (None, 1024)         0           ['batch_normalization[0][0]']
#
#  dense (Dense)                  (None, 1024)         1049600     ['dropout[0][0]']
#
#  dense_1 (Dense)                (None, 512)          524800      ['dense[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 512)         2048        ['dense_1[0][0]']
#  rmalization)
#
#  dropout_1 (Dropout)            (None, 512)          0           ['batch_normalization_1[0][0]']
#
#  dense_2 (Dense)                (None, 21)           10773       ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 8,628,821
# Trainable params: 1,588,245
# Non-trainable params: 7,040,576
# __________________________________________________________________________________________________

# %%
adam = tensorflow.keras.optimizers.Adam(
    learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07, amsgrad=False)
model.compile(optimizer = adam, 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

# %%
anne = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
checkpoint = ModelCheckpoint('denseNet121.h5', verbose=1, save_best_only=True)

datagen = ImageDataGenerator(zoom_range = 0.2, horizontal_flip=True, shear_range=0.2)


datagen.fit(data_train)
# Fits-the-model
history = model.fit_generator(datagen.flow(data_train, labels_train, batch_size=128),
               steps_per_epoch=data_train.shape[0] //124,
               epochs=10,
               verbose=2,
               callbacks=[anne, checkpoint],
               validation_data=(data_train, labels_train))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/10
#
# Epoch 00001: val_loss improved from inf to 0.68450, saving model to denseNet121.h5
# 31/31 - 31s - loss: 1.4931 - accuracy: 0.6065 - val_loss: 0.6845 - val_accuracy: 0.8072 - lr: 0.0010 - 31s/epoch - 985ms/step
# Epoch 2/10
#
# Epoch 00002: val_loss improved from 0.68450 to 0.37181, saving model to denseNet121.h5
# 31/31 - 17s - loss: 0.6409 - accuracy: 0.8100 - val_loss: 0.3718 - val_accuracy: 0.8948 - lr: 0.0010 - 17s/epoch - 537ms/step
# Epoch 3/10
#
# Epoch 00003: val_loss improved from 0.37181 to 0.35980, saving model to denseNet121.h5
# 31/31 - 17s - loss: 0.5292 - accuracy: 0.8415 - val_loss: 0.3598 - val_accuracy: 0.8961 - lr: 0.0010 - 17s/epoch - 537ms/step
# Epoch 4/10
#
# Epoch 00004: val_loss improved from 0.35980 to 0.24424, saving model to denseNet121.h5
# 31/31 - 18s - loss: 0.4781 - accuracy: 0.8516 - val_loss: 0.2442 - val_accuracy: 0.9284 - lr: 0.0010 - 18s/epoch - 585ms/step
# Epoch 5/10
#
# Epoch 00005: val_loss improved from 0.24424 to 0.18120, saving model to denseNet121.h5
# 31/31 - 17s - loss: 0.4229 - accuracy: 0.8661 - val_loss: 0.1812 - val_accuracy: 0.9497 - lr: 0.0010 - 17s/epoch - 542ms/step
# Epoch 6/10
#
# Epoch 00006: val_loss improved from 0.18120 to 0.16484, saving model to denseNet121.h5
# 31/31 - 18s - loss: 0.4180 - accuracy: 0.8681 - val_loss: 0.1648 - val_accuracy: 0.9482 - lr: 0.0010 - 18s/epoch - 580ms/step
# Epoch 7/10
#
# Epoch 00007: val_loss improved from 0.16484 to 0.13068, saving model to denseNet121.h5
# 31/31 - 18s - loss: 0.3585 - accuracy: 0.8814 - val_loss: 0.1307 - val_accuracy: 0.9649 - lr: 0.0010 - 18s/epoch - 592ms/step
# Epoch 8/10
#
# Epoch 00008: val_loss did not improve from 0.13068
# 31/31 - 18s - loss: 0.3632 - accuracy: 0.8791 - val_loss: 0.1349 - val_accuracy: 0.9596 - lr: 0.0010 - 18s/epoch - 567ms/step
# Epoch 9/10
#
# Epoch 00009: val_loss improved from 0.13068 to 0.11646, saving model to denseNet121.h5
# 31/31 - 18s - loss: 0.3026 - accuracy: 0.9040 - val_loss: 0.1165 - val_accuracy: 0.9637 - lr: 0.0010 - 18s/epoch - 587ms/step
# Epoch 10/10
#
# Epoch 00010: val_loss improved from 0.11646 to 0.10226, saving model to denseNet121.h5
# 31/31 - 17s - loss: 0.3038 - accuracy: 0.8963 - val_loss: 0.1023 - val_accuracy: 0.9708 - lr: 0.0010 - 17s/epoch - 540ms/step

# %%
ypred = model.predict(data_test)

total = 0
accurate = 0
accurateindex = []
wrongindex = []

for i in range(len(ypred)):
    if np.argmax(ypred[i]) == np.argmax(labels_test[i]):
        accurate += 1
        accurateindex.append(i)
    else:
        wrongindex.append(i)
        
        
    total += 1
    
print('Total-test-data;', total, '\taccurately-predicted-data:', accurate, '\t wrongly-predicted-data: ', total - accurate)
print('Accuracy:', round(accurate/total*100, 3), '%')
# Out:
# Total-test-data; 600 	accurately-predicted-data: 515 	 wrongly-predicted-data:  85
# Accuracy: 85.833 %

# %%
wrongindex[00]
# Out:
# 12

# %%
import cv2
import os
# img = cv2.imread(data_test[n], 1)
path = '/content/drive/MyDrive/CS114.M11/test_wrong'
for i in wrongindex:
  cv2.imwrite(os.path.join(path , str(i)+'.jpg'), i)
  cv2.waitKey(0)

# %%
Ypred = model.predict(data_test)

Ypred = np.argmax(Ypred, axis=1)
Ytrue = np.argmax(labels_test, axis=1)

cm = confusion_matrix(Ytrue, Ypred)
plt.figure(figsize=(18, 18))
ax = sns.heatmap(cm, cmap="rocket_r", fmt=".01f",annot_kws={'size':16}, annot=True, square=True, xticklabels=label, yticklabels=label)
ax.set_ylabel('Actual', fontsize=20)
ax.set_xlabel('Predicted', fontsize=20)
# Out:
# Text(0.5, 228.47999999999993, 'Predicted')

# %%
label= ['beach', 'bill', 'bookjacket', 'car', 'cat', 'clothes', 'dog', 'drink','feast', 'field', 'flower', 'food', 'fruits', 'house', 'jewels', 'motorcycle', 'mountain', 'papers', 'person', 'shoe', 'truck']
# imidx = random.sample(accurateindex, k=9)# replace with 'wrongindex'

nrows = 33
ncols = 3
fig, ax = plt.subplots(nrows,ncols,sharex=True,sharey=True,figsize=(15, 12))
row = col = 0
count = 0
for n in range(1, 600):
  if label[np.argmax(Ypred[n])] != label[np.argmax(labels_test[n])]:
      ax[row % nrows, col % ncols].imshow(data_test[n])
      ax[row % nrows, col % ncols].set_title("Predicted label :{}\nTrue label :{}".format(label[np.argmax(Ypred[n])], label[np.argmax(labels_test[n])]))
      import cv2
      import os
      path = '/content/drive/MyDrive/CS114.M11/test_wrong'
      cv2.imwrite(os.path.join(path , str(n)+'.jpg'), data_test[n])
      cv2.waitKey(0)
      if col == 2:
        row +=1
        col = 0
      else:
        col +=1
      count += 1
plt.show()

# %%
def demo_img(img_name):
    data_demo = []
    image = cv2.imread(img_name)
    image = cv2.resize(image, (224, 224))
    image = img_to_array(image)
    data_demo.append(image)
    data_demo = np.array(data_demo, dtype="float32") / 255.0
    ypred_demo = model.predict(data_demo)
    print("predict label: ",label[np.argmax(ypred_demo)])

# %%
img_name = "/content/OIP (4).jpg"
demo_img(img_name)
plt.imshow(cv2.imread(img_name))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-25-adc2495d3b1c> in <module>()
#       1 img_name = "/content/OIP (4).jpg"
# ----> 2 demo_img(img_name)
#       3 plt.imshow(cv2.imread(img_name))
#
# <ipython-input-24-bb2db4507a19> in demo_img(img_name)
#       2     data_demo = []
#       3     image = cv2.imread(img_name)
# ----> 4     image = cv2.resize(image, (224, 224))
#       5     image = img_to_array(image)
#       6     data_demo.append(image)
#
# error: OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
